# %%
import pandas as pd
import scipy
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.preprocessing import LabelEncoder

letter_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data"
names = ["lettr", "x-box", "y-box", "width", "high", "onpix", "x-bar", "y-bar", "x2bar", 
         "y2bar", "xybar", "x2ybr", "xy2br", "x-ege", "xegvy", "y-ege", "yegvx"]
letter_data = pd.read_csv(letter_url, names=names)

# %%
### Parametros
plt.rcParams["figure.figsize"] = (10,10)
plt.rcParams.update({'font.size': 22})

# %%
from sklearn.model_selection import train_test_split

# %%
X = letter_data.drop(["lettr"], axis=1)
Y = letter_data['lettr']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()

# %%
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='gini', splitter='random', max_features=i, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
# plotting the points  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='gini', splitter='best', max_features=i, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='random', max_features=i, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=10)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=2, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=10)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=3, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=10)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=4, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=5, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=6, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=7, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=10)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=8, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=9, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=10, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=11, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=12, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=13, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=14, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=15, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=16, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=17, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
features=range(1,len(names))
means=[]
stds=[]
for i in features:
  tree = DecisionTreeClassifier(criterion='entropy', splitter='best', max_features=i, max_depth=18, presort=True, random_state=42)
  all_accuracies = cross_val_score(estimator=tree, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
plt.plot(features, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - features') 
plt.xlim(1,16)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(features,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Decision Tree Progression!') 
  
# function to show the plot 
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
neigh=range(1,50)
means=[]
stds=[]
for i in neigh:
  knn = KNeighborsClassifier(n_neighbors=i, weights='uniform', metric='minkowski', p=1)
  all_accuracies = cross_val_score(estimator=knn, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
# plotting the points  
plt.plot(neigh, means) 
  
# naming the x axis 
plt.xlabel('x - neighbors') 
plt.xlim(1,50)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)
  
# giving a title to my graph 
plt.title('KNN Progression!') 

for x, y in zip(neigh,means):
  plt.text(x, y, str("%.2f" % y))
  
# function to show the plot 
plt.show()

# %%
neigh=range(1,50)
means=[]
stds=[]
for i in neigh:
  knn = KNeighborsClassifier(n_neighbors=i, weights='uniform', metric='minkowski', p=2)
  all_accuracies = cross_val_score(estimator=knn, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
# plotting the points  
plt.plot(neigh, means) 
  
# naming the x axis 
plt.xlabel('x - neighbors') 
plt.xlim(1,50)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)
  
# giving a title to my graph 
plt.title('KNN Progression!') 

for x, y in zip(neigh,means):
  plt.text(x, y, str("%.2f" % y))
  
# function to show the plot 
plt.show()

# %%
neigh=range(1,50)
means=[]
stds=[]
for i in neigh:
  knn = KNeighborsClassifier(n_neighbors=i, weights='uniform', metric='minkowski', p=3)
  all_accuracies = cross_val_score(estimator=knn, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
# plotting the points  
plt.plot(neigh, means) 
  
# naming the x axis 
plt.xlabel('x - neighbors') 
plt.xlim(1,50)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)
  
# giving a title to my graph 
plt.title('KNN Progression!') 

for x, y in zip(neigh,means):
  plt.text(x, y, str("%.2f" % y))
  
# function to show the plot 
plt.show()

# %%
neigh=range(1,50)
means=[]
stds=[]
for i in neigh:
  knn = KNeighborsClassifier(n_neighbors=i, weights='distance', metric='minkowski', p=1)
  all_accuracies = cross_val_score(estimator=knn, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
# plotting the points  
plt.plot(neigh, means) 
  
# naming the x axis 
plt.xlabel('x - neighbors') 
plt.xlim(1,50)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)
  
# giving a title to my graph 
plt.title('KNN Progression!') 

for x, y in zip(neigh,means):
  plt.text(x, y, str("%.2f" % y))
  
# function to show the plot 
plt.show()

# %%
neigh=range(1,50)
means=[]
stds=[]
for i in neigh:
  knn = KNeighborsClassifier(n_neighbors=i, weights='uniform', metric='minkowski', p=2)
  all_accuracies = cross_val_score(estimator=knn, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
# plotting the points  
plt.plot(neigh, means) 
  
# naming the x axis 
plt.xlabel('x - neighbors') 
plt.xlim(1,50)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)
  
# giving a title to my graph 
plt.title('KNN Progression!') 

for x, y in zip(neigh,means):
  plt.text(x, y, str("%.2f" % y))
  
# function to show the plot 
plt.show()

# %%
neigh=range(1,50)
means=[]
stds=[]
for i in neigh:
  knn = KNeighborsClassifier(n_neighbors=i, weights='uniform', metric='minkowski', p=3)
  all_accuracies = cross_val_score(estimator=knn, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
# plotting the points  
plt.plot(neigh, means) 
  
# naming the x axis 
plt.xlabel('x - neighbors') 
plt.xlim(1,50)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)
  
# giving a title to my graph 
plt.title('KNN Progression!') 

for x, y in zip(neigh,means):
  plt.text(x, y, str("%.2f" % y))
  
# function to show the plot 
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
estimator=range(1,100)
means=[]
stds=[]
for i in estimator:
  forest = RandomForestClassifier(n_estimators=i, criterion='gini', random_state=42)
  all_accuracies = cross_val_score(estimator=forest, X=X_train, y=Y_train, cv=kfold)
  means.append(all_accuracies.mean())
  stds.append(all_accuracies.std())
  
# plotting the points  
plt.plot(estimator, means, marker='x') 
  
# naming the x axis 
plt.xlabel('x - estimators') 
plt.xlim(1,100)
# naming the y axis 
plt.ylabel('y - means') 
plt.ylim(0,1)

for x, y in zip(estimator,means):
  plt.text(x, y, str("%.2f" % y))

# giving a title to my graph 
plt.title('Random Forest Progression!') 
  
# function to show the plot 
plt.show()
